# %%
import sqlite3
import pandas as pd
# Create your connection.
import patents_lib as kPatents
MaDB = "patents.db"

# %% [markdown]
# # Loading DB as Pandas dataframe

# %%
cnx = sqlite3.connect(MaDB)
df = pd.read_sql_query("SELECT * FROM patents", cnx)
df
# Out:
#              p_id                                            p_title  \
# 0       US3918024            Ultrasonic array for reflection imaging
# 1       US4413629                 Portable ultrasonic Doppler System
# 2       US4159462                    Ultrasonic multi-sector scanner
# 3       US5295485                       Ultrasonic diagnostic system
# 4       US3919683  Ultrasonic wave transmitting and receiving app...
# ...           ...                                                ...
# 1332   US2483821A  US2483821A - Inspection of a solid part utiliz...
# 1333   US3269173A  US3269173A - Apparatus for ultrasonic diagnosi...
# 1334  DE2601559A1  DE2601559A1 - Ultraschallabtastvorrichtung \n ...
# 1335  DE2529112A1  DE2529112A1 - Ultraschall-applikator fuer die ...
# 1336   DE1001977B  DE1001977B - Verfahren zur Herstellung von obe...
#
#           p_date                p_link  \
# 0     1974-06-24      ./data/US3918024
# 1     1982-04-22      ./data/US4413629
# 2     1977-08-18      ./data/US4159462
# 3     1991-12-13      ./data/US5295485
# 4     1973-05-21      ./data/US3919683
# ...          ...                   ...
# 1332  1945-06-28   ./.cache/US2483821A
# 1333  1962-03-02   ./.cache/US3269173A
# 1334  1975-01-17  ./.cache/DE2601559A1
# 1335  1975-06-30  ./.cache/DE2529112A1
# 1336  1953-05-04   ./.cache/DE1001977B
#
#                                              p_inventor  \
# 0
# 1     \n    DURLEY INDUSTRIES Inc A CORP OF\n  , \n ...
# 2                         \n    General Electric Co\n
# 3                                 \n    Hitachi Ltd\n
# 4                                \n    Toshiba Corp\n
# ...                                                 ...
# 1332                      \n    Sperry Products Inc\n
# 1333  \n    Transformatoren & Roentgenwerk\n  , \n  ...
# 1334             \n    Greater Glasgow Health Board\n
# 1335                               \n    Siemens AG\n
# 1336                         \n    Rohm and Haas Co\n
#
#                                           p_beneficiary  \
# 0                                       Albert Macovski
# 1                                 Benton A. Durley, III
# 2                  Henry A. F. Rocha, Charles E. Thomas
# 3     Ryuuichi Shinomura, Wasao Takasugi, Yoshikuni ...
# 4                     Einoshin Itamura, Kazuhiro Iinuma
# ...                                                 ...
# 1332                                  Floyd A Firestone
# 1333                                Ardenne Manfred Von
# 1334                 John Stewart Paton, Alexander Shaw
# 1335                           Richard Ing Grad Soldner
# 1336                         Warren Dexter Niederhauser
#
#                                              p_abstract  \
# 0     Abstract\n\nA pulsed ultrasonic beam is focuse...
# 1     Abstract\n\nA portable ultrasonic Doppler Syst...
# 2     Abstract\n\nA steered beam B-scan ultrasonic i...
# 3     Abstract\n\nAn ultrasonic diagnostic system in...
# 4     Abstract\n\nAn ultrasonic wave transmitting an...
# ...                                                 ...
# 1332  \n\nout. 4, 1949. \nF. A. FIRESTONE INSPECTION...
# 1333  \n\n0, 1966 M. VON ARDENNE APPABATUS FOR ULTRA...
# 1334                                               \n\n
# 1335                                               \n\n
# 1336                                               \n\n
#
#                                              p_backward  \
# 0     US3090030A, US3262307A, US3341807A, US3685051A...
# 1        US3972320A, US4086916A, US4248241A, GB1584347A
# 2                    US3919683A, US4030343A, US4075598A
# 3     US3964296A, JPS55151952A, US4246792A, JPS57170...
# 4                                US3090030A, US3693415A
# ...                                                 ...
# 1332                           GB191325207A, US2378237A
# 1333     US2763153A, US2913602A, US2984098A, US3023611A
# 1334
# 1335
# 1336                                          DE694178C
#
#                                               p_forward
# 0     US4058003A, US4069467A, US4080838A, DE2643918A...
# 1     EP0146073A2, US4582066A, EP0219988A2, US467451...
# 2     US4241608A, US4245250A, DE3025628A1, US4252026...
# 3     US5622429A, US5644410A, US5690114A, US5722412A...
# 4     US4019169A, DE2709647A1, US4058003A, US4070642...
# ...                                                 ...
# 1332  US2524208A, US2625035A, US2682766A, US2746480A...
# 1333  US3310977A, US3345863A, US3426585A, US3626930A...
# 1334  US4143554A, EP0000067B1, DE3105097A1, DE3722942A1
# 1335               US4143554A, EP0018771A1, DE3316186C1
# 1336                                         US4143554A
#
# [1337 rows x 9 columns]

# %%
# Out:
#            p_id                                            p_title  \
# 0     US3918024            Ultrasonic array for reflection imaging
# 1     US4413629                 Portable ultrasonic Doppler System
# 2     US4159462                    Ultrasonic multi-sector scanner
# 3     US5295485                       Ultrasonic diagnostic system
# 4     US3919683  Ultrasonic wave transmitting and receiving app...
# ..          ...                                                ...
# 936  US5435311A  US5435311A - Ultrasound therapeutic system \n ...
# 937  US5257629A  US5257629A - Methods and apparatus for the exa...
# 938  US5402793A  US5402793A - Ultrasonic transesophageal probe ...
# 939  US4211949A  US4211949A - Wear plate for piezoelectric ultr...
# 940  US5165413A  US5165413A - Steered linear color doppler imag...
#
#          p_date               p_link  \
# 0    1974-06-24     ./data/US3918024
# 1    1982-04-22     ./data/US4413629
# 2    1977-08-18     ./data/US4159462
# 3    1991-12-13     ./data/US5295485
# 4    1973-05-21     ./data/US3919683
# ..          ...                  ...
# 936  1989-06-27  ./.cache/US5435311A
# 937  1989-05-26  ./.cache/US5257629A
# 938  1993-11-19  ./.cache/US5402793A
# 939  1978-11-08  ./.cache/US4211949A
# 940  1988-09-13  ./.cache/US5165413A
#
#                                             p_inventor  \
# 0
# 1    \n    DURLEY INDUSTRIES Inc A CORP OF\n  , \n ...
# 2                        \n    General Electric Co\n
# 3                                \n    Hitachi Ltd\n
# 4                               \n    Toshiba Corp\n
# ..                                                 ...
# 936                              \n    Hitachi Ltd\n
# 937               \n    Intravascular Research Ltd\n
# 938     \n    Advanced Technology Laboratories Inc\n
# 939                      \n    General Electric Co\n
# 940                              \n    Acuson Corp\n
#
#                                          p_beneficiary  \
# 0                                      Albert Macovski
# 1                                Benton A. Durley, III
# 2                 Henry A. F. Rocha, Charles E. Thomas
# 3    Ryuuichi Shinomura, Wasao Takasugi, Yoshikuni ...
# 4                    Einoshin Itamura, Kazuhiro Iinuma
# ..                                                 ...
# 936  Shinichiro Umemura, Kenichi Kawabata, Koji Kaw...
# 937  Richard I. Kitney, Keith Straughan, Martin T. ...
# 938  George P. Gruner, John D. Fraser, Loc Nguyen, ...
# 939                   Axel F. Brisken, Lowell S. Smith
# 940  Samuel H. Maslak, Donald J. Burch, John N. Wri...
#
#                                             p_abstract  \
# 0    Abstract\n\nA pulsed ultrasonic beam is focuse...
# 1    Abstract\n\nA portable ultrasonic Doppler Syst...
# 2    Abstract\n\nA steered beam B-scan ultrasonic i...
# 3    Abstract\n\nAn ultrasonic diagnostic system in...
# 4    Abstract\n\nAn ultrasonic wave transmitting an...
# ..                                                 ...
# 936  Abstract\n\nIn an ultrasound therapeutic syste...
# 937  Abstract\n\nThe internal examination of a huma...
# 938  Abstract\n\nA multiplane TEE probe is provided...
# 939  Abstract\n\nA linear transducer array for 90° ...
# 940  Abstract\n\nA dual mode color Doppler imaging ...
#
#                                             p_backward  \
# 0    US3090030A, US3262307A, US3341807A, US3685051A...
# 1       US3972320A, US4086916A, US4248241A, GB1584347A
# 2                   US3919683A, US4030343A, US4075598A
# 3    US3964296A, JPS55151952A, US4246792A, JPS57170...
# 4                               US3090030A, US3693415A
# ..                                                 ...
# 936  US4483345A, US4620546A, US4658828A, DE3704909A...
# 937  US4398540A, US4672963A, US4821731A, WO19890041...
# 938  US3779234A, US4473077A, US4543960A, US4967752A...
# 939  US2527217A, US3277451A, US3409869A, US3457543A...
# 940  US4612937A, US4850362A, US4893628A, US4972838A...
#
#                                              p_forward  \
# 0    US4058003A, US4069467A, US4080838A, DE2643918A...
# 1    EP0146073A2, US4582066A, EP0219988A2, US467451...
# 2    US4241608A, US4245250A, DE3025628A1, US4252026...
# 3    US5622429A, US5644410A, US5690114A, US5722412A...
# 4    US4019169A, DE2709647A1, US4058003A, US4070642...
# ..                                                 ...
# 936  US5558092A, US5759162A, US5769790A, EP0872262A...
# 937  DE4418868A1, US5453575A, US5465726A, US5490510...
# 938  WO1996000522A1, US5513639A, US5590658A, EP0754...
# 939  US4297607A, US4319489A, US4323077A, US4325257A...
# 940  US5285788A, US5349524A, US5402789A, US5437281A...
#
#                                                     BW  \
# 0    [US3090030A, US3262307A, US3341807A, US3685051...
# 1     [US3972320A, US4086916A, US4248241A, GB1584347A]
# 2                 [US3919683A, US4030343A, US4075598A]
# 3    [US3964296A, JPS55151952A, US4246792A, JPS5717...
# 4                             [US3090030A, US3693415A]
# ..                                                 ...
# 936  [US4483345A, US4620546A, US4658828A, DE3704909...
# 937  [US4398540A, US4672963A, US4821731A, WO1989004...
# 938  [US3779234A, US4473077A, US4543960A, US4967752...
# 939  [US2527217A, US3277451A, US3409869A, US3457543...
# 940  [US4612937A, US4850362A, US4893628A, US4972838...
#
#                                                     FW
# 0    [US4058003A, US4069467A, US4080838A, DE2643918...
# 1    [EP0146073A2, US4582066A, EP0219988A2, US46745...
# 2    [US4241608A, US4245250A, DE3025628A1, US425202...
# 3    [US5622429A, US5644410A, US5690114A, US5722412...
# 4    [US4019169A, DE2709647A1, US4058003A, US407064...
# ..                                                 ...
# 936  [US5558092A, US5759162A, US5769790A, EP0872262...
# 937  [DE4418868A1, US5453575A, US5465726A, US549051...
# 938  [WO1996000522A1, US5513639A, US5590658A, EP075...
# 939  [US4297607A, US4319489A, US4323077A, US4325257...
# 940  [US5285788A, US5349524A, US5402789A, US5437281...
#
# [941 rows x 11 columns]

# %%
df["Lower"] = df.p_abstract.apply(lambda x: x.lower())
DF = df[df['Lower'].str.contains("sector")]
DF.head()
# Out:
#         p_id                                            p_title      p_date  \
# 0  US3918024            Ultrasonic array for reflection imaging  1974-06-24
# 2  US4159462                    Ultrasonic multi-sector scanner  1977-08-18
# 3  US5295485                       Ultrasonic diagnostic system  1991-12-13
# 4  US3919683  Ultrasonic wave transmitting and receiving app...  1973-05-21
# 5  US4075598  Ultrasonic wave transmitting and receiving app...  1975-04-25
#
#              p_link                     p_inventor  \
# 0  ./data/US3918024
# 2  ./data/US4159462  \n    General Electric Co\n
# 3  ./data/US5295485          \n    Hitachi Ltd\n
# 4  ./data/US3919683         \n    Toshiba Corp\n
# 5  ./data/US4075598         \n    Toshiba Corp\n
#
#                                        p_beneficiary  \
# 0                                    Albert Macovski
# 2               Henry A. F. Rocha, Charles E. Thomas
# 3  Ryuuichi Shinomura, Wasao Takasugi, Yoshikuni ...
# 4                  Einoshin Itamura, Kazuhiro Iinuma
# 5  Kinya Takamizawa, Einoshin Itamura, Kazuhiro I...
#
#                                           p_abstract  \
# 0  Abstract\n\nA pulsed ultrasonic beam is focuse...
# 2  Abstract\n\nA steered beam B-scan ultrasonic i...
# 3  Abstract\n\nAn ultrasonic diagnostic system in...
# 4  Abstract\n\nAn ultrasonic wave transmitting an...
# 5  Abstract\n\nProvided is an ultrasonic wave tra...
#
#                                           p_backward  \
# 0  US3090030A, US3262307A, US3341807A, US3685051A...
# 2                 US3919683A, US4030343A, US4075598A
# 3  US3964296A, JPS55151952A, US4246792A, JPS57170...
# 4                             US3090030A, US3693415A
# 5                 US3166731A, US3918025A, US3919683A
#
#                                            p_forward  \
# 0  US4058003A, US4069467A, US4080838A, DE2643918A...
# 2  US4241608A, US4245250A, DE3025628A1, US4252026...
# 3  US5622429A, US5644410A, US5690114A, US5722412A...
# 4  US4019169A, DE2709647A1, US4058003A, US4070642...
# 5  US4159462A, US4241608A, US4253338A, US4319489A...
#
#                                                   BW  \
# 0  [US3090030A, US3262307A, US3341807A, US3685051...
# 2               [US3919683A, US4030343A, US4075598A]
# 3  [US3964296A, JPS55151952A, US4246792A, JPS5717...
# 4                           [US3090030A, US3693415A]
# 5               [US3166731A, US3918025A, US3919683A]
#
#                                                   FW  \
# 0  [US4058003A, US4069467A, US4080838A, DE2643918...
# 2  [US4241608A, US4245250A, DE3025628A1, US425202...
# 3  [US5622429A, US5644410A, US5690114A, US5722412...
# 4  [US4019169A, DE2709647A1, US4058003A, US407064...
# 5  [US4159462A, US4241608A, US4253338A, US4319489...
#
#                                                Lower
# 0  abstract\n\na pulsed ultrasonic beam is focuse...
# 2  abstract\n\na steered beam b-scan ultrasonic i...
# 3  abstract\n\nan ultrasonic diagnostic system in...
# 4  abstract\n\nan ultrasonic wave transmitting an...
# 5  abstract\n\nprovided is an ultrasonic wave tra...

# %%
BWlist = list(filter(None,(", ".join(DF.p_backward.tolist())).split(", ")))
FWlist = list(filter(None,(", ".join(DF.p_forward.tolist())).split(", ")))

BackCount = pd.Series(BWlist).value_counts().reset_index()
BackCount.columns = ["p_id","countBW"]
BC = BackCount.merge(df,how="outer")
ToGetRetro = BC[(BC.countBW > 0) & (BC.p_link.isna())].head(20).p_id.to_list()
ToGetRetro
# Out:
# ['US4932414A',
#  'US5655535A',
#  'US4507582A',
#  'US5085221A',
#  'US4315514A',
#  'US4211948A',
#  'US5255681A',
#  'US5163436A',
#  'US5373845A',
#  'US4938216A',
#  'US4865042A',
#  'US6036646A',
#  'US5215680A',
#  'US5817021A',
#  'US5360007A',
#  'US4344327A',
#  'US5222501A',
#  'US5879303A',
#  'US4601296A',
#  'US5022399A']

# %%
for Patent in ToGetRetro:
    kPatents.get_soup(Patent,MaDB)
# Out:
# Processing US4932414A - System of therapeutic ultrasound and real-time ultrasonic scanning
#         - Google Patents (US4932414A)
# Processing US5655535A - 3-Dimensional compound ultrasound field of view
#         - Google Patents (US5655535A)
# Processing US4507582A - Matching region for damped piezoelectric ultrasonic apparatus
#         - Google Patents (US4507582A)
# Processing US5085221A - Ultrasonic imaging probe
#         - Google Patents (US5085221A)
# Processing US4315514A - Method and apparatus for selective cell destruction
#         - Google Patents (US4315514A)
# Processing US4211948A - Front surface matched piezoelectric ultrasonic transducer array with wide field of view
#         - Google Patents (US4211948A)
# Processing US5255681A - Ultrasonic wave diagnosing apparatus having an ultrasonic wave transmitting and receiving part transmitting and receiving ultrasonic waves
#         - Google Patents (US5255681A)
# Processing US5163436A - Ultrasonic probe system
#         - Google Patents (US5163436A)
# Processing US5373845A - Apparatus and method for forward looking volume imaging
#         - Google Patents (US5373845A)
# Processing US4938216A - Mechanically scanned line-focus ultrasound hyperthermia system
#         - Google Patents (US4938216A)
# Processing US4865042A - Ultrasonic irradiation system
#         - Google Patents (US4865042A)
# Processing US6036646A - Method and apparatus for three dimensional ultrasound imaging
#         - Google Patents (US6036646A)
# Processing US5215680A - Method for the production of medical-grade lipid-coated microbubbles, paramagnetic labeling of such microbubbles and therapeutic uses of microbubbles
#         - Google Patents (US5215680A)
# Processing US5817021A - Therapy apparatus for treating conditions of the heart and heart-proximate vessels
#         - Google Patents (US5817021A)
# Processing US5360007A - Ultrasonic apparatus
#         - Google Patents (US5360007A)
# Processing US4344327A - Electronic scanning ultrasonic diagnostic system
#         - Google Patents (US4344327A)
# Processing US5222501A - Methods for the diagnosis and ablation treatment of ventricular tachycardia
#         - Google Patents (US5222501A)
# Processing US5879303A - Ultrasonic diagnostic imaging of response frequency differing from transmit frequency
#         - Google Patents (US5879303A)
# Processing US4601296A - Hyperthermia apparatus
#         - Google Patents (US4601296A)
# Processing US5022399A - Venoscope
#         - Google Patents (US5022399A)

# %% [markdown]
# # Same thing for forward looking patents

# %%
FWlist = list(filter(None,(", ".join(DF.p_forward.tolist())).split(", ")))

BackCount = pd.Series(FWlist).value_counts().reset_index()
BackCount.columns = ["p_id","countFW"]
BC = BackCount.merge(df,how="outer")
ToGetForward = BC[(BC.countFW > 0) & (BC.p_link.isna())].head(20).p_id.to_list()
ToGetForward
# Out:
# ['US9504446B2',
#  'US9149658B2',
#  'US10420960B2',
#  'US8858471B2',
#  'US8915870B2',
#  'US10537304B2',
#  'US10561862B2',
#  'US8636665B2',
#  'US9566454B2',
#  'US8663112B2',
#  'US8444562B2',
#  'US9320537B2',
#  'US8690778B2',
#  'US20040122319A1',
#  'US8932224B2',
#  'US8915853B2',
#  'US5921932A',
#  'US20110201976A1',
#  'US9272162B2',
#  'US20050240127A1']

# %%
for Patent in ToGetForward:
    kPatents.get_soup(Patent,MaDB)
# Out:
# Processing US9504446B2 - Systems and methods for coupling an ultrasound source to tissue
#         - Google Patents (US9504446B2)
# Processing US9149658B2 - Systems and methods for ultrasound treatment
#         - Google Patents (US9149658B2)
# Processing US10420960B2 - Devices and methods for multi-focus ultrasound therapy
#         - Google Patents (US10420960B2)
# Processing US8858471B2 - Methods and systems for ultrasound treatment
#         - Google Patents (US8858471B2)
# Processing US8915870B2 - Method and system for treating stretch marks
#         - Google Patents (US8915870B2)
# Processing US10537304B2 - Hand wand for ultrasonic cosmetic treatment and imaging
#         - Google Patents (US10537304B2)
# Processing US10561862B2 - Ultrasound treatment device and methods of use
#         - Google Patents (US10561862B2)
# Processing US8636665B2 - Method and system for ultrasound treatment of fat
#         - Google Patents (US8636665B2)
# Processing US9566454B2 - Method and sysem for non-ablative acne treatment and prevention
#         - Google Patents (US9566454B2)
# Processing US8663112B2 - Methods and systems for fat reduction and/or cellulite treatment
#         - Google Patents (US8663112B2)
# Processing US8444562B2 - System and method for treating muscle, tendon, ligament and cartilage tissue
#         - Google Patents (US8444562B2)
# Processing US9320537B2 - Methods for noninvasive skin tightening
#         - Google Patents (US9320537B2)
# Processing US8690778B2 - Energy-based tissue tightening
#         - Google Patents (US8690778B2)
# Processing US20040122319A1 - High frequency, high frame-rate ultrasound imaging system
#         - Google Patents (US20040122319A1)
# Processing US8932224B2 - Energy based hyperhidrosis treatment
#         - Google Patents (US8932224B2)
# Processing US8915853B2 - Methods for face and neck lifts
#         - Google Patents (US8915853B2)
# Processing US5921932A - Method and apparatus for a baseband processor of a receive beamformer system
#         - Google Patents (US5921932A)
# Processing US20110201976A1 - Laparoscopic hifu probe
#         - Google Patents (US20110201976A1)
# Processing US9272162B2 - Imaging, therapy, and temperature monitoring ultrasonic method
#         - Google Patents (US9272162B2)
# Processing US20050240127A1 - Ultrasound phased arrays
#         - Google Patents (US20050240127A1)

# %% [markdown]
# # Saving DF to a CSV that is compressed

# %%
df.to_csv("AllPatentsStructure.csv.gz", 
           index=False, 
           compression="gzip")

# %%
df
# Out:
#            p_id                                            p_title  \
# 0     US3918024            Ultrasonic array for reflection imaging
# 1     US4413629                 Portable ultrasonic Doppler System
# 2     US4159462                    Ultrasonic multi-sector scanner
# 3     US5295485                       Ultrasonic diagnostic system
# 4     US3919683  Ultrasonic wave transmitting and receiving app...
# ..          ...                                                ...
# 936  US5435311A  US5435311A - Ultrasound therapeutic system \n ...
# 937  US5257629A  US5257629A - Methods and apparatus for the exa...
# 938  US5402793A  US5402793A - Ultrasonic transesophageal probe ...
# 939  US4211949A  US4211949A - Wear plate for piezoelectric ultr...
# 940  US5165413A  US5165413A - Steered linear color doppler imag...
#
#          p_date               p_link  \
# 0    1974-06-24     ./data/US3918024
# 1    1982-04-22     ./data/US4413629
# 2    1977-08-18     ./data/US4159462
# 3    1991-12-13     ./data/US5295485
# 4    1973-05-21     ./data/US3919683
# ..          ...                  ...
# 936  1989-06-27  ./.cache/US5435311A
# 937  1989-05-26  ./.cache/US5257629A
# 938  1993-11-19  ./.cache/US5402793A
# 939  1978-11-08  ./.cache/US4211949A
# 940  1988-09-13  ./.cache/US5165413A
#
#                                             p_inventor  \
# 0
# 1    \n    DURLEY INDUSTRIES Inc A CORP OF\n  , \n ...
# 2                        \n    General Electric Co\n
# 3                                \n    Hitachi Ltd\n
# 4                               \n    Toshiba Corp\n
# ..                                                 ...
# 936                              \n    Hitachi Ltd\n
# 937               \n    Intravascular Research Ltd\n
# 938     \n    Advanced Technology Laboratories Inc\n
# 939                      \n    General Electric Co\n
# 940                              \n    Acuson Corp\n
#
#                                          p_beneficiary  \
# 0                                      Albert Macovski
# 1                                Benton A. Durley, III
# 2                 Henry A. F. Rocha, Charles E. Thomas
# 3    Ryuuichi Shinomura, Wasao Takasugi, Yoshikuni ...
# 4                    Einoshin Itamura, Kazuhiro Iinuma
# ..                                                 ...
# 936  Shinichiro Umemura, Kenichi Kawabata, Koji Kaw...
# 937  Richard I. Kitney, Keith Straughan, Martin T. ...
# 938  George P. Gruner, John D. Fraser, Loc Nguyen, ...
# 939                   Axel F. Brisken, Lowell S. Smith
# 940  Samuel H. Maslak, Donald J. Burch, John N. Wri...
#
#                                             p_abstract  \
# 0    Abstract\n\nA pulsed ultrasonic beam is focuse...
# 1    Abstract\n\nA portable ultrasonic Doppler Syst...
# 2    Abstract\n\nA steered beam B-scan ultrasonic i...
# 3    Abstract\n\nAn ultrasonic diagnostic system in...
# 4    Abstract\n\nAn ultrasonic wave transmitting an...
# ..                                                 ...
# 936  Abstract\n\nIn an ultrasound therapeutic syste...
# 937  Abstract\n\nThe internal examination of a huma...
# 938  Abstract\n\nA multiplane TEE probe is provided...
# 939  Abstract\n\nA linear transducer array for 90° ...
# 940  Abstract\n\nA dual mode color Doppler imaging ...
#
#                                             p_backward  \
# 0    US3090030A, US3262307A, US3341807A, US3685051A...
# 1       US3972320A, US4086916A, US4248241A, GB1584347A
# 2                   US3919683A, US4030343A, US4075598A
# 3    US3964296A, JPS55151952A, US4246792A, JPS57170...
# 4                               US3090030A, US3693415A
# ..                                                 ...
# 936  US4483345A, US4620546A, US4658828A, DE3704909A...
# 937  US4398540A, US4672963A, US4821731A, WO19890041...
# 938  US3779234A, US4473077A, US4543960A, US4967752A...
# 939  US2527217A, US3277451A, US3409869A, US3457543A...
# 940  US4612937A, US4850362A, US4893628A, US4972838A...
#
#                                              p_forward
# 0    US4058003A, US4069467A, US4080838A, DE2643918A...
# 1    EP0146073A2, US4582066A, EP0219988A2, US467451...
# 2    US4241608A, US4245250A, DE3025628A1, US4252026...
# 3    US5622429A, US5644410A, US5690114A, US5722412A...
# 4    US4019169A, DE2709647A1, US4058003A, US4070642...
# ..                                                 ...
# 936  US5558092A, US5759162A, US5769790A, EP0872262A...
# 937  DE4418868A1, US5453575A, US5465726A, US5490510...
# 938  WO1996000522A1, US5513639A, US5590658A, EP0754...
# 939  US4297607A, US4319489A, US4323077A, US4325257A...
# 940  US5285788A, US5349524A, US5402789A, US5437281A...
#
# [941 rows x 9 columns]

# %% [markdown]
# # Making pages

# %%
topics = ["electromechanical"]

# %%
df["BW"] = df.p_backward.apply(lambda x: str(x).split(", "))
df["FW"] = df.p_forward.apply(lambda x: str(x).split(", "))
AllSaved = df.p_id.to_list()

# %%
for k in range(len(df)):
    sID = df.iloc[k]["p_id"]
    sTitle = df.iloc[k]["p_title"]
    sDate = df.iloc[k]["p_date"]
    sInventor = df.iloc[k]["p_inventor"]
    sBenef = df.iloc[k]["p_beneficiary"]
    sAbstract = df.iloc[k]["p_abstract"]
    sBW = df.iloc[k]["BW"]
    sFW = df.iloc[k]["FW"]
    
    MD = "# "+sID+" - "+sTitle.replace("- Google Patents","").replace("\n","").strip()+"\n\n"
    MD += "## Details\n\n"
    MD += "* Date: "+sDate.strip()+"\n"
    MD += "* Inventor: "+sInventor.strip()+"\n"    
    MD += "* Beneficiary: "+sBenef.strip()+"\n"  
    MD += "\n## Other patents\n"   
    if len(sBW):
        MD += "\n### Backwards\n * "
        MD += "\n * ".join(sBW)
    if len(sFW):
        MD += "\n### Forward\n * "
        MD += "\n * ".join(sFW)
    MD += "\n## Abstract\n\n"   
    MD += sAbstract.strip()
    
    for Referenced in AllSaved:
        MD = MD.replace(Referenced, "["+Referenced+"]("+Referenced+".md)")
        
    MD = "Source: ["+sID+"](https://patents.google.com/patent/"+sID+")" + "\n\n"+MD
    
    f= open("md/"+sID+".md","w+")
    f.write(MD)
    f.close()

# %%
AllSaved[0]

# %%
df['CleanDate']= pd.to_datetime(df['p_date']) 
df = df.sort_values(by=['CleanDate']).dropna(subset=['CleanDate'])
df

# %%
MD = "# Time frame\n\n"

for k in range(len(df)):
    sID = df.iloc[k]["p_id"]
    sTitle = df.iloc[k]["p_title"]
    sDate = df.iloc[k]["p_date"]
    sInventor = df.iloc[k]["p_inventor"]
    sBenef = df.iloc[k]["p_beneficiary"]
    sAbstract = df.iloc[k]["p_abstract"]
    sBW = df.iloc[k]["BW"]
    sFW = df.iloc[k]["FW"]
    MD += "* "+sDate+": ["+sTitle.replace("- Google Patents","").replace("\n","").strip()+"]("+sID+".md)\n"
MD += "\n\n Done!"
f= open("md/Readme.md","w+")
f.write(MD)
f.close()
